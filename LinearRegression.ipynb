# %%
# EDA Packages
import pandas as pd
import numpy as np
# Visualization Packages
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the Data Set

import types
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_b2f5c20b29b84bc78cd217146f6bb11d = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='6iJNoH4AUBpeYnIutC3E5tHvF7QZ91yxTibS5TvDjKJp',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_b2f5c20b29b84bc78cd217146f6bb11d.get_object(Bucket='predictlifeexpectency-donotdelete-pr-qrlidnfvnqlveb',Key='data.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df = pd.read_csv(body)
df.head()
# Out:
#        Country      Status  Year  Adult Mortality  infant deaths  \
# 0  Afghanistan  Developing  2015            263.0             62
# 1  Afghanistan  Developing  2014            271.0             64
# 2  Afghanistan  Developing  2013            268.0             66
# 3  Afghanistan  Developing  2012            272.0             69
# 4  Afghanistan  Developing  2011            275.0             71
#
#    percentage expenditure  under-five deaths   Total expenditure  Diphtheria   \
# 0               71.279624                  83               8.16         65.0
# 1               73.523582                  86               8.18         62.0
# 2               73.219243                  89               8.13         64.0
# 3               78.184215                  93               8.52         67.0
# 4                7.097109                  97               7.87         68.0
#
#     thinness  1-19 years  ...  Schooling  Hepatitis  Measles    BMI    HIV  \
# 0                   17.2  ...       10.1       65.0      1154   19.1   0.1
# 1                   17.5  ...       10.0       62.0       492   18.6   0.1
# 2                   17.7  ...        9.9       64.0       430   18.1   0.1
# 3                   17.9  ...        9.8       67.0      2787   17.6   0.1
# 4                   18.2  ...        9.5       68.0      3013   17.2   0.1
#
#           GDP  Population  Alcohol  Polio  Life
# 0  584.259210  33736494.0     0.01    6.0  65.0
# 1  612.696514    327582.0     0.01   58.0  59.9
# 2  631.744976  31731688.0     0.01   62.0  59.9
# 3  669.959000   3696958.0     0.01   67.0  59.5
# 4   63.537231   2978599.0     0.01   68.0  59.2
#
# [5 rows x 22 columns]

# %%
# Descriptive Statistics
df.head()
# Out:
#        Country      Status  Year  Adult Mortality  infant deaths  \
# 0  Afghanistan  Developing  2015            263.0             62
# 1  Afghanistan  Developing  2014            271.0             64
# 2  Afghanistan  Developing  2013            268.0             66
# 3  Afghanistan  Developing  2012            272.0             69
# 4  Afghanistan  Developing  2011            275.0             71
#
#    percentage expenditure  under-five deaths   Total expenditure  Diphtheria   \
# 0               71.279624                  83               8.16         65.0
# 1               73.523582                  86               8.18         62.0
# 2               73.219243                  89               8.13         64.0
# 3               78.184215                  93               8.52         67.0
# 4                7.097109                  97               7.87         68.0
#
#     thinness  1-19 years  ...  Schooling  Hepatitis  Measles    BMI    HIV  \
# 0                   17.2  ...       10.1       65.0      1154   19.1   0.1
# 1                   17.5  ...       10.0       62.0       492   18.6   0.1
# 2                   17.7  ...        9.9       64.0       430   18.1   0.1
# 3                   17.9  ...        9.8       67.0      2787   17.6   0.1
# 4                   18.2  ...        9.5       68.0      3013   17.2   0.1
#
#           GDP  Population  Alcohol  Polio  Life
# 0  584.259210  33736494.0     0.01    6.0  65.0
# 1  612.696514    327582.0     0.01   58.0  59.9
# 2  631.744976  31731688.0     0.01   62.0  59.9
# 3  669.959000   3696958.0     0.01   67.0  59.5
# 4   63.537231   2978599.0     0.01   68.0  59.2
#
# [5 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Country', 'Status', 'Year', 'Adult Mortality', 'infant deaths',
#        'percentage expenditure', 'under-five deaths ', 'Total expenditure',
#        'Diphtheria ', ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling', 'Hepatitis', 'Measles ',
#        ' BMI ', ' HIV', 'GDP', 'Population', 'Alcohol', 'Polio', 'Life'],
#       dtype='object')

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.describe()
# Out:
#               Year  Adult Mortality  infant deaths  percentage expenditure  \
# count  2938.000000      2928.000000    2938.000000             2938.000000
# mean   2007.518720       164.796448      30.303948              738.251295
# std       4.613841       124.292079     117.926501             1987.914858
# min    2000.000000         1.000000       0.000000                0.000000
# 25%    2004.000000        74.000000       0.000000                4.685343
# 50%    2008.000000       144.000000       3.000000               64.912906
# 75%    2012.000000       228.000000      22.000000              441.534144
# max    2015.000000       723.000000    1800.000000            19479.911610
#
#        under-five deaths   Total expenditure  Diphtheria   \
# count         2938.000000         2712.00000  2919.000000
# mean            42.035739            5.93819    82.324084
# std            160.445548            2.49832    23.716912
# min              0.000000            0.37000     2.000000
# 25%              0.000000            4.26000    78.000000
# 50%              4.000000            5.75500    93.000000
# 75%             28.000000            7.49250    97.000000
# max           2500.000000           17.60000    99.000000
#
#         thinness  1-19 years   thinness 5-9 years  \
# count            2904.000000          2904.000000
# mean                4.839704             4.870317
# std                 4.420195             4.508882
# min                 0.100000             0.100000
# 25%                 1.600000             1.500000
# 50%                 3.300000             3.300000
# 75%                 7.200000             7.200000
# max                27.700000            28.600000
#
#        Income composition of resources    Schooling    Hepatitis  \
# count                      2771.000000  2775.000000  2385.000000
# mean                          0.627551    11.992793    80.940461
# std                           0.210904     3.358920    25.070016
# min                           0.000000     0.000000     1.000000
# 25%                           0.493000    10.100000    77.000000
# 50%                           0.677000    12.300000    92.000000
# 75%                           0.779000    14.300000    97.000000
# max                           0.948000    20.700000    99.000000
#
#             Measles          BMI           HIV            GDP    Population  \
# count    2938.000000  2904.000000  2938.000000    2490.000000  2.286000e+03
# mean     2419.592240    38.321247     1.742103    7483.158469  1.275338e+07
# std     11467.272489    20.044034     5.077785   14270.169342  6.101210e+07
# min         0.000000     1.000000     0.100000       1.681350  3.400000e+01
# 25%         0.000000    19.300000     0.100000     463.935626  1.957932e+05
# 50%        17.000000    43.500000     0.100000    1766.947595  1.386542e+06
# 75%       360.250000    56.200000     0.800000    5910.806335  7.420359e+06
# max    212183.000000    87.300000    50.600000  119172.741800  1.293859e+09
#
#            Alcohol        Polio         Life
# count  2744.000000  2919.000000  2928.000000
# mean      4.602861    82.550188    69.224932
# std       4.052413    23.428046     9.523867
# min       0.010000     3.000000    36.300000
# 25%       0.877500    78.000000    63.100000
# 50%       3.755000    93.000000    72.100000
# 75%       7.702500    97.000000    75.700000
# max      17.870000    99.000000    89.000000

# %%
df.dtypes
# Out:
# Country                             object
# Status                              object
# Year                                 int64
# Adult Mortality                    float64
# infant deaths                        int64
# percentage expenditure             float64
# under-five deaths                    int64
# Total expenditure                  float64
# Diphtheria                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# Hepatitis                          float64
# Measles                              int64
#  BMI                               float64
#  HIV                               float64
# GDP                                float64
# Population                         float64
# Alcohol                            float64
# Polio                              float64
# Life                               float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Country                              0
# Status                               0
# Year                                 0
# Adult Mortality                     10
# infant deaths                        0
# percentage expenditure               0
# under-five deaths                    0
# Total expenditure                  226
# Diphtheria                          19
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# Hepatitis                          553
# Measles                              0
#  BMI                                34
#  HIV                                 0
# GDP                                448
# Population                         652
# Alcohol                            194
# Polio                               19
# Life                                10
# dtype: int64

# %%
df.shape
# Out:
# (2938, 22)

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (1649, 22)

# %%
# Correlation Between Attributes using Pearson Correlation
df.corr(method='pearson')
# The correlation is Using only the float(numeric instead of all) hence we need to convert all to numeric not objects
# Out:
#                                      Year  Adult Mortality  infant deaths  \
# Year                             1.000000        -0.037092       0.008029
# Adult Mortality                 -0.037092         1.000000       0.042450
# infant deaths                    0.008029         0.042450       1.000000
# percentage expenditure           0.069553        -0.237610      -0.090765
# under-five deaths                0.010479         0.060365       0.996906
# Total expenditure                0.059493        -0.085227      -0.146951
# Diphtheria                       0.029641        -0.191429      -0.161871
#  thinness  1-19 years            0.019757         0.272230       0.463415
#  thinness 5-9 years              0.014122         0.286723       0.461908
# Income composition of resources  0.122892        -0.442203      -0.134754
# Schooling                        0.088732        -0.421171      -0.214372
# Hepatitis                        0.114897        -0.105225      -0.231769
# Measles                         -0.053822        -0.003967       0.532680
#  BMI                             0.005739        -0.351542      -0.234425
#  HIV                            -0.123405         0.550691       0.007712
# GDP                              0.096421        -0.255035      -0.098092
# Population                       0.012567        -0.015012       0.671758
# Alcohol                         -0.113365        -0.175535      -0.106217
# Polio                           -0.016699        -0.199853      -0.156929
# Life                             0.050771        -0.702523      -0.169074
#
#                                  percentage expenditure  under-five deaths   \
# Year                                           0.069553            0.010479
# Adult Mortality                               -0.237610            0.060365
# infant deaths                                 -0.090765            0.996906
# percentage expenditure                         1.000000           -0.092158
# under-five deaths                             -0.092158            1.000000
# Total expenditure                              0.183872           -0.145803
# Diphtheria                                     0.134813           -0.178448
#  thinness  1-19 years                         -0.255035            0.464785
#  thinness 5-9 years                           -0.255635            0.462289
# Income composition of resources                0.402170           -0.148097
# Schooling                                      0.422088           -0.226013
# Hepatitis                                      0.016760           -0.240766
# Measles                                       -0.063071            0.517506
#  BMI                                           0.242738           -0.242137
#  HIV                                          -0.095085            0.019476
# GDP                                            0.959299           -0.100331
# Population                                    -0.016792            0.658680
# Alcohol                                        0.417047           -0.101082
# Polio                                          0.128626           -0.171164
# Life                                           0.409631           -0.192265
#
#                                  Total expenditure  Diphtheria   \
# Year                                      0.059493     0.029641
# Adult Mortality                          -0.085227    -0.191429
# infant deaths                            -0.146951    -0.161871
# percentage expenditure                    0.183872     0.134813
# under-five deaths                        -0.145803    -0.178448
# Total expenditure                         1.000000     0.129915
# Diphtheria                                0.129915     1.000000
#  thinness  1-19 years                    -0.209872    -0.187242
#  thinness 5-9 years                      -0.217865    -0.180952
# Income composition of resources           0.183653     0.343262
# Schooling                                 0.243783     0.350398
# Hepatitis                                 0.113327     0.588990
# Measles                                  -0.113583    -0.058606
#  BMI                                      0.189469     0.176295
#  HIV                                      0.043101    -0.117601
# GDP                                       0.180373     0.158438
# Population                               -0.079962    -0.039898
# Alcohol                                   0.214885     0.242951
# Polio                                     0.119768     0.609245
# Life                                      0.174718     0.341331
#
#                                   thinness  1-19 years   thinness 5-9 years  \
# Year                                          0.019757             0.014122
# Adult Mortality                               0.272230             0.286723
# infant deaths                                 0.463415             0.461908
# percentage expenditure                       -0.255035            -0.255635
# under-five deaths                             0.464785             0.462289
# Total expenditure                            -0.209872            -0.217865
# Diphtheria                                   -0.187242            -0.180952
#  thinness  1-19 years                         1.000000             0.927913
#  thinness 5-9 years                           0.927913             1.000000
# Income composition of resources              -0.453679            -0.438484
# Schooling                                    -0.491199            -0.472482
# Hepatitis                                    -0.129406            -0.133251
# Measles                                       0.180642             0.174946
#  BMI                                         -0.547018            -0.554094
#  HIV                                          0.172592             0.183147
# GDP                                          -0.277498            -0.277959
# Population                                    0.282529             0.277913
# Alcohol                                      -0.403755            -0.386208
# Polio                                        -0.164070            -0.174489
# Life                                         -0.457838            -0.457508
#
#                                  Income composition of resources  Schooling  \
# Year                                                    0.122892   0.088732
# Adult Mortality                                        -0.442203  -0.421171
# infant deaths                                          -0.134754  -0.214372
# percentage expenditure                                  0.402170   0.422088
# under-five deaths                                      -0.148097  -0.226013
# Total expenditure                                       0.183653   0.243783
# Diphtheria                                              0.343262   0.350398
#  thinness  1-19 years                                  -0.453679  -0.491199
#  thinness 5-9 years                                    -0.438484  -0.472482
# Income composition of resources                         1.000000   0.784741
# Schooling                                               0.784741   1.000000
# Hepatitis                                               0.184921   0.215182
# Measles                                                -0.058277  -0.115660
#  BMI                                                    0.510505   0.554844
#  HIV                                                   -0.248590  -0.211840
# GDP                                                     0.446856   0.467947
# Population                                             -0.008132  -0.040312
# Alcohol                                                 0.561074   0.616975
# Polio                                                   0.314682   0.350147
# Life                                                    0.721083   0.727630
#
#                                  Hepatitis  Measles       BMI        HIV  \
# Year                              0.114897 -0.053822  0.005739 -0.123405
# Adult Mortality                  -0.105225 -0.003967 -0.351542  0.550691
# infant deaths                    -0.231769  0.532680 -0.234425  0.007712
# percentage expenditure            0.016760 -0.063071  0.242738 -0.095085
# under-five deaths                -0.240766  0.517506 -0.242137  0.019476
# Total expenditure                 0.113327 -0.113583  0.189469  0.043101
# Diphtheria                        0.588990 -0.058606  0.176295 -0.117601
#  thinness  1-19 years            -0.129406  0.180642 -0.547018  0.172592
#  thinness 5-9 years              -0.133251  0.174946 -0.554094  0.183147
# Income composition of resources   0.184921 -0.058277  0.510505 -0.248590
# Schooling                         0.215182 -0.115660  0.554844 -0.211840
# Hepatitis                         1.000000 -0.124800  0.143302 -0.094802
# Measles                          -0.124800  1.000000 -0.153245 -0.003522
#  BMI                              0.143302 -0.153245  1.000000 -0.210897
#  HIV                             -0.094802 -0.003522 -0.210897  1.000000
# GDP                               0.041850 -0.064768  0.266114 -0.108081
# Population                       -0.129723  0.321946 -0.081416 -0.027801
# Alcohol                           0.109889 -0.050110  0.353396 -0.027113
# Polio                             0.463331 -0.057850  0.186268 -0.107885
# Life                              0.199935 -0.068881  0.542042 -0.592236
#
#                                       GDP  Population   Alcohol     Polio  \
# Year                             0.096421    0.012567 -0.113365 -0.016699
# Adult Mortality                 -0.255035   -0.015012 -0.175535 -0.199853
# infant deaths                   -0.098092    0.671758 -0.106217 -0.156929
# percentage expenditure           0.959299   -0.016792  0.417047  0.128626
# under-five deaths               -0.100331    0.658680 -0.101082 -0.171164
# Total expenditure                0.180373   -0.079962  0.214885  0.119768
# Diphtheria                       0.158438   -0.039898  0.242951  0.609245
#  thinness  1-19 years           -0.277498    0.282529 -0.403755 -0.164070
#  thinness 5-9 years             -0.277959    0.277913 -0.386208 -0.174489
# Income composition of resources  0.446856   -0.008132  0.561074  0.314682
# Schooling                        0.467947   -0.040312  0.616975  0.350147
# Hepatitis                        0.041850   -0.129723  0.109889  0.463331
# Measles                         -0.064768    0.321946 -0.050110 -0.057850
#  BMI                             0.266114   -0.081416  0.353396  0.186268
#  HIV                            -0.108081   -0.027801 -0.027113 -0.107885
# GDP                              1.000000   -0.020369  0.443433  0.156809
# Population                      -0.020369    1.000000 -0.028880 -0.045387
# Alcohol                          0.443433   -0.028880  1.000000  0.240315
# Polio                            0.156809   -0.045387  0.240315  1.000000
# Life                             0.441322   -0.022305  0.402718  0.327294
#
#                                      Life
# Year                             0.050771
# Adult Mortality                 -0.702523
# infant deaths                   -0.169074
# percentage expenditure           0.409631
# under-five deaths               -0.192265
# Total expenditure                0.174718
# Diphtheria                       0.341331
#  thinness  1-19 years           -0.457838
#  thinness 5-9 years             -0.457508
# Income composition of resources  0.721083
# Schooling                        0.727630
# Hepatitis                        0.199935
# Measles                         -0.068881
#  BMI                             0.542042
#  HIV                            -0.592236
# GDP                              0.441322
# Population                      -0.022305
# Alcohol                          0.402718
# Polio                            0.327294
# Life                             1.000000

# %%
#One Hot Encoding Using get_dummies
df1 = df

# %%
pd.set_option('precision',3)
df1.corr()
# Out:
#                                   Year  Adult Mortality  infant deaths  \
# Year                             1.000           -0.037          0.008
# Adult Mortality                 -0.037            1.000          0.042
# infant deaths                    0.008            0.042          1.000
# percentage expenditure           0.070           -0.238         -0.091
# under-five deaths                0.010            0.060          0.997
# Total expenditure                0.059           -0.085         -0.147
# Diphtheria                       0.030           -0.191         -0.162
#  thinness  1-19 years            0.020            0.272          0.463
#  thinness 5-9 years              0.014            0.287          0.462
# Income composition of resources  0.123           -0.442         -0.135
# Schooling                        0.089           -0.421         -0.214
# Hepatitis                        0.115           -0.105         -0.232
# Measles                         -0.054           -0.004          0.533
#  BMI                             0.006           -0.352         -0.234
#  HIV                            -0.123            0.551          0.008
# GDP                              0.096           -0.255         -0.098
# Population                       0.013           -0.015          0.672
# Alcohol                         -0.113           -0.176         -0.106
# Polio                           -0.017           -0.200         -0.157
# Life                             0.051           -0.703         -0.169
#
#                                  percentage expenditure  under-five deaths   \
# Year                                              0.070               0.010
# Adult Mortality                                  -0.238               0.060
# infant deaths                                    -0.091               0.997
# percentage expenditure                            1.000              -0.092
# under-five deaths                                -0.092               1.000
# Total expenditure                                 0.184              -0.146
# Diphtheria                                        0.135              -0.178
#  thinness  1-19 years                            -0.255               0.465
#  thinness 5-9 years                              -0.256               0.462
# Income composition of resources                   0.402              -0.148
# Schooling                                         0.422              -0.226
# Hepatitis                                         0.017              -0.241
# Measles                                          -0.063               0.518
#  BMI                                              0.243              -0.242
#  HIV                                             -0.095               0.019
# GDP                                               0.959              -0.100
# Population                                       -0.017               0.659
# Alcohol                                           0.417              -0.101
# Polio                                             0.129              -0.171
# Life                                              0.410              -0.192
#
#                                  Total expenditure  Diphtheria   \
# Year                                         0.059        0.030
# Adult Mortality                             -0.085       -0.191
# infant deaths                               -0.147       -0.162
# percentage expenditure                       0.184        0.135
# under-five deaths                           -0.146       -0.178
# Total expenditure                            1.000        0.130
# Diphtheria                                   0.130        1.000
#  thinness  1-19 years                       -0.210       -0.187
#  thinness 5-9 years                         -0.218       -0.181
# Income composition of resources              0.184        0.343
# Schooling                                    0.244        0.350
# Hepatitis                                    0.113        0.589
# Measles                                     -0.114       -0.059
#  BMI                                         0.189        0.176
#  HIV                                         0.043       -0.118
# GDP                                          0.180        0.158
# Population                                  -0.080       -0.040
# Alcohol                                      0.215        0.243
# Polio                                        0.120        0.609
# Life                                         0.175        0.341
#
#                                   thinness  1-19 years   thinness 5-9 years  \
# Year                                             0.020                0.014
# Adult Mortality                                  0.272                0.287
# infant deaths                                    0.463                0.462
# percentage expenditure                          -0.255               -0.256
# under-five deaths                                0.465                0.462
# Total expenditure                               -0.210               -0.218
# Diphtheria                                      -0.187               -0.181
#  thinness  1-19 years                            1.000                0.928
#  thinness 5-9 years                              0.928                1.000
# Income composition of resources                 -0.454               -0.438
# Schooling                                       -0.491               -0.472
# Hepatitis                                       -0.129               -0.133
# Measles                                          0.181                0.175
#  BMI                                            -0.547               -0.554
#  HIV                                             0.173                0.183
# GDP                                             -0.277               -0.278
# Population                                       0.283                0.278
# Alcohol                                         -0.404               -0.386
# Polio                                           -0.164               -0.174
# Life                                            -0.458               -0.458
#
#                                  Income composition of resources  Schooling  \
# Year                                                       0.123      0.089
# Adult Mortality                                           -0.442     -0.421
# infant deaths                                             -0.135     -0.214
# percentage expenditure                                     0.402      0.422
# under-five deaths                                         -0.148     -0.226
# Total expenditure                                          0.184      0.244
# Diphtheria                                                 0.343      0.350
#  thinness  1-19 years                                     -0.454     -0.491
#  thinness 5-9 years                                       -0.438     -0.472
# Income composition of resources                            1.000      0.785
# Schooling                                                  0.785      1.000
# Hepatitis                                                  0.185      0.215
# Measles                                                   -0.058     -0.116
#  BMI                                                       0.511      0.555
#  HIV                                                      -0.249     -0.212
# GDP                                                        0.447      0.468
# Population                                                -0.008     -0.040
# Alcohol                                                    0.561      0.617
# Polio                                                      0.315      0.350
# Life                                                       0.721      0.728
#
#                                  Hepatitis  Measles    BMI     HIV    GDP  \
# Year                                 0.115    -0.054  0.006 -0.123  0.096
# Adult Mortality                     -0.105    -0.004 -0.352  0.551 -0.255
# infant deaths                       -0.232     0.533 -0.234  0.008 -0.098
# percentage expenditure               0.017    -0.063  0.243 -0.095  0.959
# under-five deaths                   -0.241     0.518 -0.242  0.019 -0.100
# Total expenditure                    0.113    -0.114  0.189  0.043  0.180
# Diphtheria                           0.589    -0.059  0.176 -0.118  0.158
#  thinness  1-19 years               -0.129     0.181 -0.547  0.173 -0.277
#  thinness 5-9 years                 -0.133     0.175 -0.554  0.183 -0.278
# Income composition of resources      0.185    -0.058  0.511 -0.249  0.447
# Schooling                            0.215    -0.116  0.555 -0.212  0.468
# Hepatitis                            1.000    -0.125  0.143 -0.095  0.042
# Measles                             -0.125     1.000 -0.153 -0.004 -0.065
#  BMI                                 0.143    -0.153  1.000 -0.211  0.266
#  HIV                                -0.095    -0.004 -0.211  1.000 -0.108
# GDP                                  0.042    -0.065  0.266 -0.108  1.000
# Population                          -0.130     0.322 -0.081 -0.028 -0.020
# Alcohol                              0.110    -0.050  0.353 -0.027  0.443
# Polio                                0.463    -0.058  0.186 -0.108  0.157
# Life                                 0.200    -0.069  0.542 -0.592  0.441
#
#                                  Population  Alcohol  Polio   Life
# Year                                  0.013   -0.113 -0.017  0.051
# Adult Mortality                      -0.015   -0.176 -0.200 -0.703
# infant deaths                         0.672   -0.106 -0.157 -0.169
# percentage expenditure               -0.017    0.417  0.129  0.410
# under-five deaths                     0.659   -0.101 -0.171 -0.192
# Total expenditure                    -0.080    0.215  0.120  0.175
# Diphtheria                           -0.040    0.243  0.609  0.341
#  thinness  1-19 years                 0.283   -0.404 -0.164 -0.458
#  thinness 5-9 years                   0.278   -0.386 -0.174 -0.458
# Income composition of resources      -0.008    0.561  0.315  0.721
# Schooling                            -0.040    0.617  0.350  0.728
# Hepatitis                            -0.130    0.110  0.463  0.200
# Measles                               0.322   -0.050 -0.058 -0.069
#  BMI                                 -0.081    0.353  0.186  0.542
#  HIV                                 -0.028   -0.027 -0.108 -0.592
# GDP                                  -0.020    0.443  0.157  0.441
# Population                            1.000   -0.029 -0.045 -0.022
# Alcohol                              -0.029    1.000  0.240  0.403
# Polio                                -0.045    0.240  1.000  0.327
# Life                                 -0.022    0.403  0.327  1.000

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df1.corr(),annot=True)
plt.show()

# %%
df1.skew()
# Out:
# Year                               -0.200
# Adult Mortality                     1.276
# infant deaths                       8.477
# percentage expenditure              4.981
# under-five deaths                   8.341
# Total expenditure                   0.213
# Diphtheria                         -2.487
#  thinness  1-19 years               1.821
#  thinness 5-9 years                 1.867
# Income composition of resources    -1.155
# Schooling                          -0.128
# Hepatitis                          -1.793
# Measles                             7.958
#  BMI                               -0.234
#  HIV                                4.974
# GDP                                 4.517
# Population                         14.186
# Alcohol                             0.663
# Polio                              -2.360
# Life                               -0.629
# dtype: float64

# %%
# %matplotlib inline

# %%
# Histogram
plt.figure(figsize=(50,30))
df1.hist()
plt.show()

# %%
sns.distplot(df['Life'])

# %% [markdown]
# # Feature Selection
# SelectKBest
# Select the features with the strongest relationship with output
# Recursive Feature Elimination
# Identify which features contribute the most to predicting the target output

# %%
Xfeatures = df1.values[:,3:21]
Xfeatures.shape
# Out:
# (1649, 18)

# %%
Ylabel=df1.iloc[:,21:22].values
Ylabel=Ylabel.astype('int')
Ylabel.shape
# Out:
# (1649, 1)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
# Using a model to check 
from sklearn.linear_model import LinearRegression
# Don't be confuse about the name it is a classification algorithm not a regression
modelLogit = LinearRegression()
skb = SelectKBest(score_func=chi2,k=4)
skbfit = skb.fit(Xfeatures,Ylabel)

# %%
skbfit.scores_
best_features = skbfit.transform(Xfeatures)

# %%
# Highest scores show the best features
print("Scores",skbfit.scores_)
# Out:
# Scores [8.25271563e+04 6.21556498e+04 3.16994267e+06 9.04633777e+04
#  2.34408679e+02 1.39536034e+03 1.89756798e+03 1.94667034e+03
#  5.12176805e+01 6.49556781e+02 1.13295133e+03 2.52228609e+06
#  5.68247125e+03 2.15517366e+04 1.76068176e+07 2.56437767e+10
#  1.85392433e+03 1.48641695e+03]

# %%
mybestscores = list(skbfit.scores_)
myfeaturenames =  ['Adult Mortality', 'infant deaths',
       'percentage expenditure', 'under-five deaths ', 'Total expenditure',
       'Diphtheria ', ' thinness  1-19 years', ' thinness 5-9 years',
       'Income composition of resources', 'Schooling', 'Hepatitis', 'Measles ',
       ' BMI ', ' HIV', 'GDP', 'Population', 'Alcohol', 'Polio']

# %%
for b,f in zip(mybestscores,myfeaturenames):
    print(f'"Feature":{f} => {b/100}')
# Out:
# "Feature":Adult Mortality => 825.2715631190596
# "Feature":infant deaths => 621.5564975817078
# "Feature":percentage expenditure => 31699.426721974825
# "Feature":under-five deaths  => 904.6337771478106
# "Feature":Total expenditure => 2.34408678750114
# "Feature":Diphtheria  => 13.953603380489753
# "Feature": thinness  1-19 years => 18.975679750684627
# "Feature": thinness 5-9 years => 19.46670341011427
# "Feature":Income composition of resources => 0.5121768053185084
# "Feature":Schooling => 6.495567805396442
# "Feature":Hepatitis => 11.329513267362943
# "Feature":Measles  => 25222.86085103762
# "Feature": BMI  => 56.82471252202732
# "Feature": HIV => 215.5173656568889
# "Feature":GDP => 176068.17575928153
# "Feature":Population => 256437767.37161598
# "Feature":Alcohol => 18.5392433444999
# "Feature":Polio => 14.86416954580768

# %%
# Hence the highest feature scores are GDP,Population,Measles,HIV,AdultMortality,infantdeaths.

# %% [markdown]
# Using Recursive Feature Elimination to check which feature contribute the most to predicting the target results

# %%
from sklearn.feature_selection import RFE
rfe = RFE(modelLogit,3)
rfe_fit = rfe.fit(Xfeatures,Ylabel)
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
print("Number of Features",rfe_fit.n_features_)
print("Feature Names",list(df1.columns)[3:21])
print("Selected Features",rfe_fit.support_)
print("Features Ranking",rfe_fit.ranking_)
# Out:
# Number of Features 3
# Feature Names ['Adult Mortality', 'infant deaths', 'percentage expenditure', 'under-five deaths ', 'Total expenditure', 'Diphtheria ', ' thinness  1-19 years', ' thinness 5-9 years', 'Income composition of resources', 'Schooling', 'Hepatitis', 'Measles ', ' BMI ', ' HIV', 'GDP', 'Population', 'Alcohol', 'Polio']
# Selected Features [False False False False False False False False  True  True False False
#  False  True False False False False]
# Features Ranking [ 7  4 13  5  2  8 11  3  1  1  9 15  6  1 14 16 12 10]

# %% [markdown]
# Feature Importance
# The larger the score the more important the feature or attribute
# ExtraTreesClassifier

# %%
from sklearn.ensemble import ExtraTreesClassifier
modelExtra = ExtraTreesClassifier()
modelExtra.fit(Xfeatures,Ylabel)
print(modelExtra.feature_importances_)
# Out:
# [0.08436262 0.04747512 0.05216922 0.04705451 0.05930924 0.04299783
#  0.06638623 0.06303957 0.08137908 0.06698768 0.04269697 0.03649634
#  0.07186982 0.03797481 0.05662986 0.0434671  0.06086191 0.0388421 ]
# /opt/conda/envs/Python36/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   app.launch_new_instance()

# %%
myimportantfeature = list(modelExtra.feature_importances_)

# %%
for imp,mf in zip(myimportantfeature,myfeaturenames):
    print(f'"Feature":{mf} => {imp*100}')
# Out:
# "Feature":Adult Mortality => 8.436262236338642
# "Feature":infant deaths => 4.747512211737816
# "Feature":percentage expenditure => 5.2169216760268045
# "Feature":under-five deaths  => 4.705451215858464
# "Feature":Total expenditure => 5.930923684052184
# "Feature":Diphtheria  => 4.299782862875863
# "Feature": thinness  1-19 years => 6.638623113003137
# "Feature": thinness 5-9 years => 6.303956711888725
# "Feature":Income composition of resources => 8.137907531023211
# "Feature":Schooling => 6.698767563363484
# "Feature":Hepatitis => 4.269696724324663
# "Feature":Measles  => 3.649633695761735
# "Feature": BMI  => 7.186982266650417
# "Feature": HIV => 3.797481174394171
# "Feature":GDP => 5.662986471133557
# "Feature":Population => 4.346709769784825
# "Feature":Alcohol => 6.0861912971874
# "Feature":Polio => 3.884209794594905

# %%
# Split Data set
from sklearn.model_selection import train_test_split
seed = 7 # used to enable randomness being reproducible
X_train,X_test,Y_train,Y_test = train_test_split(Xfeatures,Ylabel,test_size=0.33,random_state=7)

# %%
#using our LinearRegression
modelLogit.fit(X_train, Y_train)
result = modelLogit.score(X_test, Y_test)
print("Accuracy: ",result*100.0)
# Out:
# Accuracy:  82.06587846348596

# %%
predictions = modelLogit.predict(X_test)
plt.scatter(Y_test,predictions)

# %%
X_test
# Out:
# array([[169.0, 0, 24.70841046, ..., 25979.0, 10.14, 92.0],
#        [22.0, 0, 47.08931143, ..., 159328.0, 5.46, 97.0],
#        [267.0, 5, 180.35378590000002, ..., 474516.0, 6.79, 99.0],
#        ...,
#        [369.0, 81, 212.92293250000003, ..., 22549547.0, 7.01, 63.0],
#        [65.0, 0, 1259.940376, ..., 385.0, 0.01, 99.0],
#        [184.0, 2, 653.6925016, ..., 625777.0, 2.42, 92.0]], dtype=object)

# %%
X_predict = np.array([28,1500,34.85942671,2000,4.25,65,27.1,28,0.536,9.7,6,64185,13.9,0.3,792.259698,1161977719,1.37,66])

# %%
type(X_predict)
# Out:
# numpy.ndarray

# %%
X_predict.shape
# Out:
# (18,)

# %%
newX = X_predict.reshape(-1,18)

# %%
newX.shape
# Out:
# (1, 18)

# %%
print(modelLogit.predict(newX))
# Out:
# [[65.63513524]]

# %%
from sklearn import metrics

# %%
print("MAE",metrics.mean_absolute_error(Y_test,predictions))
print("MSE",metrics.mean_squared_error(Y_test,predictions))
print("RMSE",np.sqrt(metrics.mean_squared_error(Y_test,predictions)))
# Out:
# MAE 2.759414881506819
# MSE 13.07628923541577
# RMSE 3.616115213238617

# %%
# using Cross Validation with KFold
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %%
# Using our LinearRegression
num_folds = 10
seed = 7
kfold = KFold(n_splits=num_folds, random_state=seed)
results = cross_val_score(modelLogit, Xfeatures, Ylabel, cv=kfold)
print(results)
print("Mean Accuracy:", results.mean()*100.0)
print("STD Accuracy:", results.std()*100.0)
# Out:
# [0.77951452 0.81465613 0.80864819 0.77219993 0.73898672 0.86794344
#  0.65368183 0.75568781 0.77073101 0.80586957]
# Mean Accuracy: 77.67919137539046
# STD Accuracy: 5.357104968797014

# %%
# !pip install watson_machine_learning_client
# Out:
# Requirement already satisfied: watson_machine_learning_client in /opt/conda/envs/Python36/lib/python3.6/site-packages (1.0.376)
# Requirement already satisfied: lomond in /opt/conda/envs/Python36/lib/python3.6/site-packages (from watson_machine_learning_client) (0.3.3)
# Requirement already satisfied: tabulate in /opt/conda/envs/Python36/lib/python3.6/site-packages (from watson_machine_learning_client) (0.8.2)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from watson_machine_learning_client) (2.21.0)
# Requirement already satisfied: urllib3 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from watson_machine_learning_client) (1.24.1)
# Requirement already satisfied: certifi in /opt/conda/envs/Python36/lib/python3.6/site-packages (from watson_machine_learning_client) (2020.4.5.1)
# Requirement already satisfied: ibm-cos-sdk in /opt/conda/envs/Python36/lib/python3.6/site-packages (from watson_machine_learning_client) (2.4.3)
# Requirement already satisfied: tqdm in /opt/conda/envs/Python36/lib/python3.6/site-packages (from watson_machine_learning_client) (4.31.1)
# Requirement already satisfied: pandas in /opt/conda/envs/Python36/lib/python3.6/site-packages (from watson_machine_learning_client) (0.24.1)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from lomond->watson_machine_learning_client) (1.12.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->watson_machine_learning_client) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->watson_machine_learning_client) (3.0.4)
# Requirement already satisfied: ibm-cos-sdk-s3transfer==2.*,>=2.0.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ibm-cos-sdk->watson_machine_learning_client) (2.4.3)
# Requirement already satisfied: ibm-cos-sdk-core==2.*,>=2.0.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ibm-cos-sdk->watson_machine_learning_client) (2.4.3)
# Requirement already satisfied: numpy>=1.12.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pandas->watson_machine_learning_client) (1.15.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pandas->watson_machine_learning_client) (2.7.5)
# Requirement already satisfied: pytz>=2011k in /opt/conda/envs/Python36/lib/python3.6/site-packages (from pandas->watson_machine_learning_client) (2018.9)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ibm-cos-sdk-core==2.*,>=2.0.0->ibm-cos-sdk->watson_machine_learning_client) (0.9.3)
# Requirement already satisfied: docutils>=0.10 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ibm-cos-sdk-core==2.*,>=2.0.0->ibm-cos-sdk->watson_machine_learning_client) (0.14)

# %%
from watson_machine_learning_client import WatsonMachineLearningAPIClient

# %%
wml_credentials={
  "apikey": "5jVk1jyke_b_b4lV4QR3EtdNeD3i49H-F49h_otCciz8",
  "instance_id": "32265a81-4310-4a0d-ac90-29b3fe842910",
  "url": "https://us-south.ml.cloud.ibm.com"

}

# %%
client=WatsonMachineLearningAPIClient(wml_credentials)

# %%
metadata = {
    client.repository.ModelMetaNames.NAME: 'LinearRegression',
    client.repository.ModelMetaNames.AUTHOR_NAME: 'Manimaran'
}

# %%
model_artifact = client.repository.store_model(modelLogit,meta_props=metadata)

# %%
published_model_uid=client.repository.get_model_uid(model_artifact)

# %%
published_model_uid
# Out:
# '127b2408-e5b2-4f3e-b79b-cabfba1c8f4d'

# %%
deployment=client.deployments.create(published_model_uid,name="LinearRegression")
# Out:
# #######################################################################################
#
# Synchronous deployment creation for uid: '127b2408-e5b2-4f3e-b79b-cabfba1c8f4d' started
#
# #######################################################################################
#
#
# INITIALIZING
# DEPLOY_SUCCESS
#
#
# ------------------------------------------------------------------------------------------------
# Successfully finished deployment creation, deployment_uid='cb66f7fc-d1c7-49f1-8ee5-4510ae678441'
# ------------------------------------------------------------------------------------------------

# %%
scoring_endpoint = client.deployments.get_scoring_url(deployment)

# %%
scoring_endpoint
# Out:
# 'https://us-south.ml.cloud.ibm.com/v3/wml_instances/32265a81-4310-4a0d-ac90-29b3fe842910/deployments/cb66f7fc-d1c7-49f1-8ee5-4510ae678441/online'
